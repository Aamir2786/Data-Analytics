# %%
# %fs ls /healthtracker/raw/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/healthtracker/raw/health_tracker_data_2020_1.json</td><td>health_tracker_data_2020_1.json</td><td>310628</td></tr><tr><td>dbfs:/healthtracker/raw/health_tracker_data_2020_2.json</td><td>health_tracker_data_2020_2.json</td><td>284670</td></tr><tr><td>dbfs:/healthtracker/raw/late/</td><td>late/</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.rm(bronzePath, recurse=True)
dbutils.fs.rm(silverPath, recurse=True)
dbutils.fs.rm(goldPath, recurse=True)
dbutils.fs.rm(checkpointPath, recurse=True)
# Out:
# Out[97]: True

# %%
basePath = "/healthtracker/"

rawPath = basePath + "raw/"
bronzePath = basePath + "bronze/"
silverPath = basePath + "silver/"
goldPath = basePath + "gold/"

checkpointPath = basePath + "checkpoints/"
bronzeCheckpoint = checkpointPath + "bronze/"
silverCheckpoint = checkpointPath + "silver/"
goldCheckpoint = checkpointPath + "gold/"

# %%
raw_schema = "value STRING"  #raw string in JSON format

raw_health_tracker_df = (
    spark.readStream.format("text").schema(raw_schema).load(rawPath)
)

# %%
display(raw_health_tracker_df, streamName="raw_df")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{"time":1577836800.0,"name":"Deborah Powell","device_id":0,"heartrate":52.8139067501}</td></tr><tr><td>{"time":1577840400.0,"name":"Deborah Powell","device_id":0,"heartrate":53.9078900098}</td></tr><tr><td>{"time":1577844000.0,"name":"Deborah Powell","device_id":0,"heartrate":52.7129593616}</td></tr><tr><td>{"time":1577847600.0,"name":"Deborah Powell","device_id":0,"heartrate":52.2880422685}</td></tr><tr><td>{"time":1577851200.0,"name":"Deborah Powell","device_id":0,"heartrate":52.5156095386}</td></tr><tr><td>{"time":1577854800.0,"name":"Deborah Powell","device_id":0,"heartrate":53.6280743846}</td></tr><tr><td>{"time":1577858400.0,"name":"Deborah Powell","device_id":0,"heartrate":52.1760037066}</td></tr><tr><td>{"time":1577862000.0,"name":"Deborah Powell","device_id":0,"heartrate":90.0456721836}</td></tr><tr><td>{"time":1577865600.0,"name":"Deborah Powell","device_id":0,"heartrate":89.4695644522}</td></tr><tr><td>{"time":1577869200.0,"name":"Deborah Powell","device_id":0,"heartrate":88.1490304138}</td></tr><tr><td>{"time":1577872800.0,"name":"Deborah Powell","device_id":0,"heartrate":86.3092976213}</td></tr><tr><td>{"time":1577876400.0,"name":"Deborah Powell","device_id":0,"heartrate":86.6672980008}</td></tr><tr><td>{"time":1577880000.0,"name":"Deborah Powell","device_id":0,"heartrate":89.2044154758}</td></tr><tr><td>{"time":1577883600.0,"name":"Deborah Powell","device_id":0,"heartrate":88.8691678316}</td></tr><tr><td>{"time":1577887200.0,"name":"Deborah Powell","device_id":0,"heartrate":87.7252170634}</td></tr><tr><td>{"time":1577890800.0,"name":"Deborah Powell","device_id":0,"heartrate":87.8357187561}</td></tr><tr><td>{"time":1577894400.0,"name":"Deborah Powell","device_id":0,"heartrate":87.1769562648}</td></tr><tr><td>{"time":1577898000.0,"name":"Deborah Powell","device_id":0,"heartrate":88.3403107931}</td></tr><tr><td>{"time":1577901600.0,"name":"Deborah Powell","device_id":0,"heartrate":88.9083484735}</td></tr><tr><td>{"time":1577905200.0,"name":"Deborah Powell","device_id":0,"heartrate":87.921434203}</td></tr><tr><td>{"time":1577908800.0,"name":"Deborah Powell","device_id":0,"heartrate":88.0534361925}</td></tr><tr><td>{"time":1577912400.0,"name":"Deborah Powell","device_id":0,"heartrate":51.5421813878}</td></tr><tr><td>{"time":1577916000.0,"name":"Deborah Powell","device_id":0,"heartrate":52.1116104838}</td></tr><tr><td>{"time":1577919600.0,"name":"Deborah Powell","device_id":0,"heartrate":52.1998346985}</td></tr><tr><td>{"time":1577836800.0,"name":"Kristin Vasser","device_id":1,"heartrate":47.5378557652}</td></tr><tr><td>{"time":1577840400.0,"name":"Kristin Vasser","device_id":1,"heartrate":48.3496970512}</td></tr><tr><td>{"time":1577844000.0,"name":"Kristin Vasser","device_id":1,"heartrate":49.1212033115}</td></tr><tr><td>{"time":1577847600.0,"name":"Kristin Vasser","device_id":1,"heartrate":47.9982802854}</td></tr><tr><td>{"time":1577851200.0,"name":"Kristin Vasser","device_id":1,"heartrate":47.841083408}</td></tr><tr><td>{"time":1577854800.0,"name":"Kristin Vasser","device_id":1,"heartrate":47.7225468025}</td></tr><tr><td>{"time":1577858400.0,"name":"Kristin Vasser","device_id":1,"heartrate":47.3041211781}</td></tr><tr><td>{"time":1577862000.0,"name":"Kristin Vasser","device_id":1,"heartrate":49.1694935562}</td></tr><tr><td>{"time":1577865600.0,"name":"Kristin Vasser","device_id":1,"heartrate":80.1944436044}</td></tr><tr><td>{"time":1577869200.0,"name":"Kristin Vasser","device_id":1,"heartrate":80.0663193135}</td></tr><tr><td>{"time":1577872800.0,"name":"Kristin Vasser","device_id":1,"heartrate":80.4780281723}</td></tr><tr><td>{"time":1577876400.0,"name":"Kristin Vasser","device_id":1,"heartrate":80.1692553854}</td></tr><tr><td>{"time":1577880000.0,"name":"Kristin Vasser","device_id":1,"heartrate":80.2008095649}</td></tr><tr><td>{"time":1577883600.0,"name":"Krist ...

# %%
from pyspark.sql.functions import *

# %%
# recording ingestion metadata

raw_health_tracker_df = raw_health_tracker_df.select(
  lit("local source").alias("datasource"),
  current_timestamp().alias("ingesttime"),
  "value",
  current_timestamp().cast("date").alias("ingestdate")
)

# %%
(raw_health_tracker_df.select(
  "datasource", "ingesttime", "value", col("ingestdate").alias("p_ingestdate")
)
.writeStream.format("delta")
.outputMode("append")
.option("checkpointLocation", bronzeCheckpoint)
.partitionBy("p_ingestdate")
.queryName("writing_raw_to_bronze")
.start(bronzePath))
# Out:
# Out[103]: <pyspark.sql.streaming.StreamingQuery at 0x7f1bb51041c0>

# %%
bronze_health_tracker_df = spark.readStream.format("delta").load(bronzePath)
display(bronze_health_tracker_df, streamName="display_bronze")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
device_id":0,"heartrate":88.9083484735}</td><td>2021-12-21</td></tr><tr><td>local source</td><td>2021-12-21T10:17:34.241+0000</td><td>{"time":1577905200.0,"name":"Deborah Powell","device_id":0,"heartrate":87.921434203}</td><td>2021-12-21</td></tr><tr><td>local source</td><td>2021-12-21T10:17:34.241+0000</td><td>{"time":1577908800.0,"name":"Deborah Powell","device_id":0,"heartrate":88.0534361925}</td><td>2021-12-21</td></tr><tr><td>local ...

# %%
display(dbutils.fs.ls(bronzePath))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/healthtracker/bronze/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/healthtracker/bronze/p_ingestdate=2021-12-21/</td><td>p_ingestdate=2021-12-21/</td><td>0</td></tr></tbody></table></div>

# %%
for s in spark.streams.active:
    print(s.name)
# Out:
# display_bronze
# raw_df
# writing_raw_to_bronze

# %%
spark.sql("""
CREATE DATABASE IF NOT EXISTS healthtracker
""")

spark.sql("USE healthtracker")
# Out:
# Out[107]: DataFrame[]

# %%
spark.sql("DROP TABLE IF EXISTS healthtracker_bronze")

spark.sql(f"""
CREATE TABLE healthtracker_bronze
USING DELTA
LOCATION "{bronzePath}"
""")
# Out:
# Out[108]: DataFrame[]

# %%
# %sql
describe detail healthtracker_bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>5defff30-d9a4-49af-b12a-e0c60148731a</td><td>healthtracker.healthtracker_bronze</td><td>null</td><td>dbfs:/healthtracker/bronze</td><td>2021-12-21T10:17:34.836+0000</td><td>2021-12-21T10:17:37.000+0000</td><td>List(p_ingestdate)</td><td>2</td><td>148800</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
describe extended healthtracker_bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>datasource</td><td>string</td><td></td></tr><tr><td>ingesttime</td><td>timestamp</td><td></td></tr><tr><td>value</td><td>string</td><td></td></tr><tr><td>p_ingestdate</td><td>date</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Part 0</td><td>p_ingestdate</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>healthtracker.healthtracker_bronze</td><td></td></tr><tr><td>Location</td><td>dbfs:/healthtracker/bronze</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
log_df = spark.read.json(bronzePath + "/_delta_log/00000000000000000000.json")
display(log_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>metaData</th><th>protocol</th><th>txn</th></tr></thead><tbody><tr><td>null</td><td>null</td><td>null</td><td>List(1, 2)</td><td>null</td></tr><tr><td>null</td><td>null</td><td>List(1640081854836, List(parquet), 5defff30-d9a4-49af-b12a-e0c60148731a, List(p_ingestdate), {"type":"struct","fields":[{"name":"datasource","type":"string","nullable":true,"metadata":{}},{"name":"ingesttime","type":"timestamp","nullable":true,"metadata":{}},{"name":"value","type":"string","nullable":true,"metadata":{}},{"name":"p_ingestdate","type":"date","nullable":true,"metadata":{}}]})</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>List(134de757-1bb1-4463-b992-ad28de5b0022, 1640081855922, 0)</td></tr><tr><td>List(true, 1640081856000, List(2021-12-21), p_ingestdate=2021-12-21/part-00000-9243f2a3-7474-4cc1-9f0e-fadaa37886c0.c000.snappy.parquet, 77448, {"numRecords":3720,"minValues":{"datasource":"local source","ingesttime":"2021-12-21T10:17:34.241Z","value":"{\"time\":1577836800.0,\"name\":\"Deb"},"maxValues":{"datasource":"local source","ingesttime":"2021-12-21T10:17:34.241Z","value":"{\"time\":1580511600.0,\"name\":\"Sam�"},"nullCount":{"datasource":0,"ingesttime":0,"value":0}}, List(1640081856000000, 268435456))</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1640081856000, List(2021-12-21), p_ingestdate=2021-12-21/part-00001-a28fc2dc-d90c-4131-b7c3-d4fd62a1aeac.c000.snappy.parquet, 71352, {"numRecords":3408,"minValues":{"datasource":"local source","ingesttime":"2021-12-21T10:17:34.241Z","value":"{\"time\":1580515200.0,\"name\":\"Deb"},"maxValues":{"datasource":"local source","ingesttime":"2021-12-21T10:17:34.241Z","value":"{\"time\":1583017200.0,\"name\":\"Sam�"},"nullCount":{"datasource":0,"ingesttime":0,"value":0}}, List(1640081856000001, 268435456))</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>List(1221-082311-eeqqlyuw, true, WriteSerializable, List(3049203889599516), STREAMING UPDATE, List(2, 148800, 7128, 0), List(0, Append, 134de757-1bb1-4463-b992-ad28de5b0022), 1640081856095, 7708969006792739, aamirsohel96@gmail.com)</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
display(bronze_health_tracker_df.groupby().count(), "bronze_count")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count</th></tr></thead><tbody><tr><td>7200</td></tr></tbody></table></div>

# %%
# performing transformation
json_schema = "device_id INTEGER, heartrate DOUBLE, name STRING, time FLOAT"

silver_health_tracker_df = bronze_health_tracker_df.select(
  from_json(col("value"), json_schema).alias("nested_json")
).select("nested_json.*")

# %%
silver_health_tracker_df = silver_health_tracker_df.select(
  "device_id",
  "heartrate",
  "name",
  from_unixtime("time").cast("timestamp").alias("eventtime"),
  from_unixtime("time").cast("date").alias("p_eventdate")
)

# %%
#writing stream to silver table

(
  silver_health_tracker_df.writeStream
  .format("delta")
  .option("checkpointLocation", silverCheckpoint)
  .outputMode("append")
  .partitionBy("p_eventdate")
  .queryName("writing_to_silver")
  .start(silverPath)
)
# Out:
# Out[113]: <pyspark.sql.streaming.StreamingQuery at 0x7f1bb5104640>

# %%
spark.sql("DROP TABLE IF EXISTS healthtracker_silver")

spark.sql(
  f"""
  CREATE TABLE healthtracker_silver
  USING DELTA
  LOCATION "{silverPath}"
  """
)
# Out:
# Out[114]: DataFrame[]

# %%
display(spark.readStream.table("healthtracker_silver") , streamName="display_silver")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
><td>1</td></tr><tr><td>2020-01-30</td><td>1</td></tr><tr><td>2020-01-31</td><td>1</td></tr><tr><td>2020-02-01</td><td>1</td></tr><tr><td>2020-02-05</td><td>2</td></tr><tr><td>2020-02-07</td><td>2</td></tr><tr><td>2020-02-09</td><td>1</td></tr><tr><td>2020-02-12</td><td>2</td></tr><tr><td>2020-02-13</td><td>1</td></tr><tr><td>2020-02-14</td><td>2</td></tr><tr><td>2020-02-16</td><td>2</td></tr><tr><td>2020-02-17</td><td>1</td></tr><tr><td>2020-02-18</td><td>1</td></tr><tr><td>2020-02-19</td><td>1</td></tr><tr><td>2020-02-23</td><td>1</td></tr><tr><td>2020-02-24</td><td>2</td></tr><tr><td>2020-02-25</td><td>2</td></tr><tr><td>2020-02-26</td><td>2</td></tr><tr><td>2020-02-27</td><td>1</td></tr><tr><td>2020-02-29</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select sum(`count(heartrate)`) from broken_readings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(count(heartrate))</th></tr></thead><tbody><tr><td>60</td></tr></tbody></table></div>

# %%
# interpolating broken values
from pyspark.sql.window import Window

dateWindow = Window.orderBy("p_eventdate")
interpolated_df =  spark.read.table("healthtracker_silver").select(
  "*",
  lag(col("heartrate")).over(dateWindow).alias("prev_value"),
  lead(col("heartrate")).over(dateWindow).alias("next_value"),
)

# %%
updates_df = interpolated_df.where(col("heartrate") < 0).select(
  "device_id",
  ((col("prev_value") + col("next_value")) / 2).alias("heartrate"),
    "eventtime",
    "name",
    "p_eventdate"
)

display(updates_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>heartrate</th><th>eventtime</th><th>name</th><th>p_eventdate</th></tr></thead><tbody><tr><td>4</td><td>101.21254699240001</td><td>2020-01-01T18:59:12.000+0000</td><td>James Hou</td><td>2020-01-01</td></tr><tr><td>1</td><td>79.4468974614</td><td>2020-01-02T10:59:12.000+0000</td><td>Kristin Vasser</td><td>2020-01-02</td></tr><tr><td>1</td><td>92.10732860255</td><td>2020-01-04T20:01:04.000+0000</td><td>Kristin Vasser</td><td>2020-01-04</td></tr><tr><td>1</td><td>54.18606982715</td><td>2020-01-06T23:00:16.000+0000</td><td>Kristin Vasser</td><td>2020-01-06</td></tr><tr><td>1</td><td>78.55314577125</td><td>2020-01-07T22:00:32.000+0000</td><td>Kristin Vasser</td><td>2020-01-07</td></tr><tr><td>2</td><td>86.8898895492</td><td>2020-01-09T15:00:16.000+0000</td><td>Sam Knopp</td><td>2020-01-09</td></tr><tr><td>4</td><td>104.77145415449999</td><td>2020-01-09T03:58:56.000+0000</td><td>James Hou</td><td>2020-01-09</td></tr><tr><td>2</td><td>97.2776487597</td><td>2020-01-12T18:59:12.000+0000</td><td>Sam Knopp</td><td>2020-01-12</td></tr><tr><td>4</td><td>63.68804357805</td><td>2020-01-12T01:59:28.000+0000</td><td>James Hou</td><td>2020-01-12</td></tr><tr><td>4</td><td>105.83667578194999</td><td>2020-01-12T08:00:00.000+0000</td><td>James Hou</td><td>2020-01-12</td></tr><tr><td>1</td><td>53.246325668</td><td>2020-01-13T03:58:56.000+0000</td><td>Kristin Vasser</td><td>2020-01-13</td></tr><tr><td>1</td><td>87.8613741164
#handle late arriving data
spark.read.json(rawPath + '/late').count()
# Out:
# Out[126]: 3480

# %%
def transform_raw(df: DataFrame) -> DataFrame:
    return df.select(
        lit("local source").alias("datasource"),
        current_timestamp().alias("ingesttime"),
        "value",
        current_timestamp().cast("date").alias("p_ingestdate"),
    )
raw_schema = "value STRING"

lateRawDF = spark.read.format("text").schema(raw_schema).load(rawPath + "/late")

transformedLateRawDF = transform_raw(lateRawDF)

# %%
# merge late-arriving data with bronze table
bronzeTable = DeltaTable.forPath(spark, bronzePath)

existing_record_match = "bronze.value = latearrivals.value"

(
  bronzeTable.alias("bronze")
  .merge(transformedLateRawDF.alias("latearrivals"), existing_record_match)
  .whenNotMatchedInsertAll()
  .execute()
)

# %%
display(
  spark.read.table("healthtracker_silver").groupby("device_id").agg(count("*"))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>count(1)</th></tr></thead><tbody><tr><td>1</td><td>1440</td></tr><tr><td>3</td><td>1440</td></tr><tr><td>4</td><td>1440</td></tr><tr><td>2</td><td>1440</td></tr><tr><td>0</td><td>1440</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM healthtracker_silver VERSION AS OF 0
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>7128</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM healthtracker_silver VERSION AS OF 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>7128</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM healthtracker_silver VERSION AS OF 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>7200</td></tr></tbody></table></div>

# %%
#building aggregate data marts

gold_health_tracker_df = silver_health_tracker_df.groupBy("device_id").agg(
  mean(col("heartrate")).alias("mean_heartrate"),
  stddev(col("heartrate")).alias("stddev_heartrate"),
  max(col("heartrate")).alias("max_heartrate")
)

# %%
tableName = "/aggregate_heartrate"
tableCheckpoint = goldCheckpoint + tableName
tablePath = goldPath + tableName

(
    gold_health_tracker_df.writeStream.format("delta")
    .outputMode("complete")
    .option("checkpointLocation", tableCheckpoint)
    .queryName("write_silver_to_gold")
    .start(tablePath)
)
# Out:
# Out[141]: <pyspark.sql.streaming.StreamingQuery at 0x7f1bb54d8640>

# %%
spark.sql("DROP TABLE IF EXISTS health_tracker_gold_aggregate_heartrate")

spark.sql(
f"""
CREATE TABLE health_tracker_gold_aggregate_heartrate
USING DELTA
LOCATION "{tablePath}"
"""
)
# Out:
# Out[142]: DataFrame[]

# %%
# %sql
select * from health_tracker_gold_aggregate_heartrate
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>mean_heartrate</th><th>stddev_heartrate</th><th>max_heartrate</th></tr></thead><tbody><tr><td>3</td><td>81.98698705713325</td><td>30.11076269005531</td><td>175.0032148522</td></tr><tr><td>4</td><td>80.24473380424911</td><td>34.22455418767537</td><td>199.092971234</td></tr><tr><td>2</td><td>80.00336378220479</td><td>31.17861138868274</td><td>189.2113455089</td></tr><tr><td>1</td><td>78.44184525561052</td><td>32.827357416972134</td><td>168.114687819</td></tr><tr><td>0</td><td>81.72446103322305</td><td>31.368367448699964</td><td>186.4790827731</td></tr></tbody></table></div>

# %%
for stream in spark.streams.active:
  stream.stop()

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
